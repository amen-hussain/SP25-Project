# %%
# Installing libraries
# !pip install seaborn
# !pip install pandas
# !pip install numpy
# !pip3 install pandas
# !pip install matplotlib
# !pip install xgboost
# !pip install catboost
# !pip install regex
# !pip install scikit-learn
# !pip install lightgbm
# !pip install missingno
# !pip install plotly.express
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# ...

# %%
import pandas as pd
import numpy as np
#import statsmodels.api as sm
import matplotlib.pyplot as plt
import csv 
from sklearn.model_selection import train_test_split  # For splitting the dataset into training and testing sets
from sklearn.linear_model import LinearRegression  # Linear regression model
from sklearn.metrics import mean_squared_error, r2_score  # Evaluation metrics
import matplotlib.pyplot as plt  # For data visualization

# %%
diabetes = pd.read_csv('/workspaces/SP25-Project/data/diabetic_data.csv')

# %%
print(diabetes.columns)
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetes.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
diabetes.replace('?', np.nan, inplace=True)

# %%
diabetes.drop_duplicates(inplace=True)

# %%
# Define the columns to drop 
columns_to_drop = [
    'encounter_id', 'weight',
    'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
    'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3',
    'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
    'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
    'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
    'tolazamide', 'examide', 'citoglipton',
    'glyburide-metformin', 'glipizide-metformin',
    'glimepiride-pioglitazone', 'metformin-rosiglitazone',
    'metformin-pioglitazone', 'change', 'diabetesMed'
]

# Drop the columns from the 'diabetes' DataFrame
diabetes_cleaned = diabetes.drop(columns=columns_to_drop)

# Show the first few rows of the cleaned DataFrame
diabetes_cleaned.head(10)
# Out:
#    patient_nbr             race  gender       age  time_in_hospital  \
# 0      8222157        Caucasian  Female    [0-10)                 1
# 1     55629189        Caucasian  Female   [10-20)                 3
# 2     86047875  AfricanAmerican  Female   [20-30)                 2
# 3     82442376        Caucasian    Male   [30-40)                 2
# 4     42519267        Caucasian    Male   [40-50)                 1
# 5     82637451        Caucasian    Male   [50-60)                 3
# 6     84259809        Caucasian    Male   [60-70)                 4
# 7    114882984        Caucasian    Male   [70-80)                 5
# 8     48330783        Caucasian  Female   [80-90)                13
# 9     63555939        Caucasian  Female  [90-100)                12
#
#    num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                  41               0                1                  0
# ...

# %%
# Define the mapping from age ranges to numeric midpoints
# Step 3: Convert age ranges to numerical midpoints
age_mapping = {
    '[0-10)': 5,
    '[10-20)': 15,
    '[20-30)': 25,
    '[30-40)': 35,
    '[40-50)': 45,
    '[50-60)': 55,
    '[60-70)': 65,
    '[70-80)': 75,
    '[80-90)': 85,
    '[90-100)': 95
}
diabetes_cleaned['age'] = diabetes_cleaned['age'].map(age_mapping)
# Preview to confirm
diabetes_cleaned[['age']].head(20)
# Out:
#     age
# 0     5
# 1    15
# 2    25
# 3    35
# 4    45
# 5    55
# 6    65
# 7    75
# 8    85
# 9    95
# 10   45
# 11   65
# 12   45
# 13   85
# 14   65
# 15   65
# 16   55
# 17   55
# 18   75
# 19   75

# %%
# Step 4: Convert 'readmitted' column to binary
# diabetes_cleaned['readmitted_binary'] = diabetes_cleaned['readmitted'].apply(lambda x: 1 if x == '<30' else 0)
# print(diabetes_cleaned['readmitted'].value_counts())
# print(diabetes_cleaned['readmitted_binary'].value_counts())

# Step 5: Encode 'gender' as binary (Male: 1, Female: 0)
# diabetes_cleaned['gender'] = diabetes_cleaned['gender'].replace({'Male': 1, 'Female': 0})
# print(diabetes_cleaned['gender'].value_counts())

# Step 6: Convert 'max_glu_serum' and 'A1Cresult' into binary
# For 'max_glu_serum', 'None' or 'Norm' = 0, anything abnormal ('>200', '>300') = 1
# diabetes_cleaned['max_glu_serum_binary'] = diabetes_cleaned['max_glu_serum'].apply(
#    lambda x: 1 if x in ['>200', '>300'] else 0
#)

# For 'A1Cresult', 'None' or 'Norm' = 0, anything abnormal ('>7', '>8') = 1
# diabetes_cleaned['A1Cresult_binary'] = diabetes_cleaned['A1Cresult'].apply(
#    lambda x: 1 if x in ['>7', '>8'] else 0
#)


# Step 7: One-hot encode 'race' only (drop first to avoid dummy variable trap)
# diabetes_cleaned = pd.get_dummies(
#     diabetes_cleaned,
#    columns=['race'],
#    drop_first=True
#)

# Step 8: Fill missing numeric values with the column mean
numeric_cols = diabetes_cleaned.select_dtypes(include=['float64', 'int64']).columns
diabetes_cleaned[numeric_cols] = diabetes_cleaned[numeric_cols].fillna(diabetes_cleaned[numeric_cols].mean())

# Step 9: Convert 'True' and 'False' values to binary if any remain
# diabetes_cleaned = diabetes_cleaned.replace({True: 1, False: 0})

# Step 10: Data preview
diabetes_cleaned.head(20)
# Out:
#     patient_nbr             race  gender  age  time_in_hospital  \
# 0       8222157        Caucasian  Female    5                 1
# 1      55629189        Caucasian  Female   15                 3
# 2      86047875  AfricanAmerican  Female   25                 2
# 3      82442376        Caucasian    Male   35                 2
# 4      42519267        Caucasian    Male   45                 1
# 5      82637451        Caucasian    Male   55                 3
# 6      84259809        Caucasian    Male   65                 4
# 7     114882984        Caucasian    Male   75                 5
# 8      48330783        Caucasian  Female   85                13
# 9      63555939        Caucasian  Female   95                12
# 10     89869032  AfricanAmerican  Female   45                 9
# 11     77391171  AfricanAmerican    Male   65                 7
# 12     85504905        Caucasian  Female   45                 7
# 13     77586282        Caucasian    Male   85                10
# ...

# %%
print(diabetes_cleaned.columns)
# Out:
# Index(['patient_nbr', 'race', 'gender', 'age', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'insulin',
#        'readmitted'],
#       dtype='object')

# %%
# Step 10:  Preview
diabetes_cleaned.head(10)
# Out:
#    patient_nbr             race  gender  age  time_in_hospital  \
# 0      8222157        Caucasian  Female    5                 1
# 1     55629189        Caucasian  Female   15                 3
# 2     86047875  AfricanAmerican  Female   25                 2
# 3     82442376        Caucasian    Male   35                 2
# 4     42519267        Caucasian    Male   45                 1
# 5     82637451        Caucasian    Male   55                 3
# 6     84259809        Caucasian    Male   65                 4
# 7    114882984        Caucasian    Male   75                 5
# 8     48330783        Caucasian  Female   85                13
# 9     63555939        Caucasian  Female   95                12
#
#    num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                  41               0                1                  0
# 1                  59               0               18                  0
# ...

# %%
# Check for missing values in the specified columns
columns_to_check = ['patient_nbr', 'race', 'gender', 'age', 'time_in_hospital',
                    'num_lab_procedures', 'num_procedures', 'num_medications',
                    'number_outpatient', 'number_emergency', 'number_inpatient',
                    'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'insulin',
                    'readmitted']

# Display missing values count for each column
missing_values = diabetes_cleaned[columns_to_check].isnull().sum()
print("Missing values in selected columns:")
print(missing_values)
# Out:
# Missing values in selected columns:
# patient_nbr               0
# race                   2273
# gender                    0
# age                       0
# time_in_hospital          0
# num_lab_procedures        0
# num_procedures            0
# num_medications           0
# number_outpatient         0
# number_emergency          0
# number_inpatient          0
# number_diagnoses          0
# max_glu_serum         96420
# A1Cresult             84748
# insulin                   0
# readmitted                0
# dtype: int64

# %%
# Save the cleaned DataFrame to a new CSV file
diabetes_cleaned.to_csv('/workspaces/SP25-Project/data/diabetes_cleaned_tableau.csv', index=False)
print("Cleaned data saved to '/workspaces/SP25-Project/data/diabetes_cleaned_tableau.csv'")
# Out:
# Cleaned data saved to '/workspaces/SP25-Project/data/diabetes_cleaned_tableau.csv'
